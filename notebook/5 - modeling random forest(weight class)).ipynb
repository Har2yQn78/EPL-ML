# %%
# Cell 1: Initial Setup, Library Imports, and Data Loading

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib # For saving/loading models
import os # For path handling

from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder # Need LabelEncoder for decoding later
from sklearn.impute import SimpleImputer # For handling NaNs from rolling averages
from sklearn.pipeline import Pipeline # Use standard sklearn Pipeline

# Import Evaluation Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, log_loss

# Import Random Forest
from sklearn.ensemble import RandomForestClassifier

from scipy.stats import randint, uniform # For tuning parameter distributions

import warnings
warnings.filterwarnings('ignore', category=UserWarning) # Suppress UserWarnings
warnings.filterwarnings('ignore', category=FutureWarning) # Suppress FutureWarnings
warnings.filterwarnings('ignore', message='No positive class found') # Suppress classification report warnings


# Set aesthetic style for plots
sns.set_style('whitegrid')

print("Libraries imported and basic setup complete.")

# Load the dataset using your specified path
DATA_PATH = "../dataset/EPL_2018-2025.csv"
try:
    df = pd.read_csv(DATA_PATH)
    print(f"Data loaded successfully from {DATA_PATH}")
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PATH}")
    print("Please ensure the file exists at the correct relative path.")
    raise FileNotFoundError(f"Data file not found at {DATA_PATH}")

# Display DataFrame Info
print("\nDataFrame Info:")
df.info()
# Out:
# Libraries imported and basic setup complete.
# Data loaded successfully from ../dataset/EPL_2018-2025.csv
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Season             2630 non-null   object
#  1   MatchDate          2630 non-null   object
#  2   HomeTeam           2630 non-null   object
#  3   AwayTeam           2630 non-null   object
#  4   FullTimeHomeGoals  2630 non-null   int64
#  5   FullTimeAwayGoals  2630 non-null   int64
#  6   FullTimeResult     2630 non-null   object
#  7   HalfTimeHomeGoals  2630 non-null   int64
#  8   HalfTimeAwayGoals  2630 non-null   int64
#  9   HalfTimeResult     2630 non-null   object
#  10  HomeShots          2630 non-null   int64
#  11  AwayShots          2630 non-null   int64
#  12  HomeShotsOnTarget  2630 non-null   int64
#  13  AwayShotsOnTarget  2630 non-null   int64
#  14  HomeCorners        2630 non-null   int64
#  15  AwayCorners        2630 non-null   int64
#  16  HomeFouls          2630 non-null   int64
#  17  AwayFouls          2630 non-null   int64
#  18  HomeYellowCards    2630 non-null   int64
#  19  AwayYellowCards    2630 non-null   int64
#  20  HomeRedCards       2630 non-null   int64
#  21  AwayRedCards       2630 non-null   int64
# dtypes: int64(16), object(6)
# memory usage: 452.2+ KB

# %%
# Cell 2: Handle MatchDate and Sort Data

print("Converting MatchDate to datetime and sorting data...")

df['MatchDate'] = pd.to_datetime(df['MatchDate'])

# Sort the DataFrame by date to ensure chronological order for time-based feature engineering
df = df.sort_values(by='MatchDate').reset_index(drop=True)

print("MatchDate converted and data sorted.")
print("\nDataFrame head after sorting:")
print(df[['Season', 'MatchDate', 'HomeTeam', 'AwayTeam']].head())
# Out:
# Converting MatchDate to datetime and sorting data...
# MatchDate converted and data sorted.
#
# DataFrame head after sorting:
#     Season  MatchDate      HomeTeam        AwayTeam
# 0  2018/19 2018-08-10    Man United       Leicester
# 1  2018/19 2018-08-11   Bournemouth         Cardiff
# 2  2018/19 2018-08-11        Fulham  Crystal Palace
# 3  2018/19 2018-08-11  Huddersfield         Chelsea
# 4  2018/19 2018-08-11     Newcastle       Tottenham

# %%
# Cell 3: Implement Team Strength/Form Features (Rolling Averages)

print("Calculating team strength/form features (rolling averages)...")

# Define the window size for rolling averages
ROLLING_WINDOW = 5

# --- get_rolling_stats_refined function ---
def get_rolling_stats_refined(team, match_date, df_sorted, window_size, location_filter=None):
    required_cols = ['MatchDate', 'HomeTeam', 'AwayTeam', 'FullTimeResult',
                     'FullTimeHomeGoals', 'FullTimeAwayGoals',
                     'HomeShots', 'AwayShots', 'HomeShotsOnTarget', 'AwayShotsOnTarget',
                     'HomeCorners', 'AwayCorners', 'HomeFouls', 'AwayFouls',
                     'HomeYellowCards', 'AwayYellowCards', 'HomeRedCards', 'AwayRedCards']

    team_matches = df_sorted[df_sorted['MatchDate'] < match_date].copy()
    team_matches_filtered = team_matches[(team_matches['HomeTeam'] == team) | (team_matches['AwayTeam'] == team)]

    if location_filter == 'Home':
        team_matches_filtered = team_matches_filtered[team_matches_filtered['HomeTeam'] == team]
    elif location_filter == 'Away':
        team_matches_filtered = team_matches_filtered[team_matches_filtered['AwayTeam'] == team]

    recent_matches = team_matches_filtered.sort_values(by='MatchDate').tail(window_size)

    if recent_matches.empty:
        return {}

    stats = {}
    valid_matches_results = recent_matches.dropna(subset=['FullTimeResult', 'HomeTeam', 'AwayTeam'])

    if not valid_matches_results.empty:
         points = valid_matches_results.apply(lambda row:
             3 if (row['HomeTeam'] == team and row['FullTimeResult'] == 'H') or \
                  (row['AwayTeam'] == team and row['FullTimeResult'] == 'A') else \
             1 if row['FullTimeResult'] == 'D' else \
             0, axis=1)
         stats['Points'] = points.mean()
    else:
         stats['Points'] = np.nan


    valid_matches_goals = recent_matches.dropna(subset=['FullTimeHomeGoals', 'FullTimeAwayGoals'])
    if not valid_matches_goals.empty:
        stats['GoalsScored'] = valid_matches_goals.apply(lambda row: row['FullTimeHomeGoals'] if row['HomeTeam'] == team else row['FullTimeAwayGoals'], axis=1).mean()
        stats['GoalsConceded'] = valid_matches_goals.apply(lambda row: row['FullTimeAwayGoals'] if row['HomeTeam'] == team else row['FullTimeHomeGoals'], axis=1).mean()
    else:
        stats['GoalsScored'] = np.nan
        stats['GoalsConceded'] = np.nan


    for col in ['Shots', 'ShotsOnTarget', 'Corners', 'Fouls', 'YellowCards', 'RedCards']:
        home_col = f'Home{col}'
        away_col = f'Away{col}'
        if home_col in recent_matches.columns and away_col in recent_matches.columns:
             valid_matches_stat = recent_matches.dropna(subset=[home_col, away_col])
             if not valid_matches_stat.empty:
                stats[col] = valid_matches_stat.apply(lambda row: row[home_col] if row['HomeTeam'] == team else row[away_col], axis=1).mean()
             else:
                stats[col] = np.nan
        else:
             stats[col] = np.nan

    return stats

# Apply the rolling stat calculation row by row
try:
    from tqdm.notebook import tqdm
    tqdm.pandas()
    use_progress_bar = True
except ImportError:
    print("tqdm.notebook not found. Install with 'pip install tqdm' for progress bar.")
    use_progress_bar = False

rolling_stats_list = []

iterator = df.iterrows()
if use_progress_bar:
    iterator = tqdm(df.iterrows(), total=df.shape[0], desc=f"Calculating {ROLLING_WINDOW}-Match Rolling Stats")

for index, row in iterator:
    home_team = row['HomeTeam']
    away_team = row['AwayTeam']
    match_date = row['MatchDate']

    home_team_home_stats = get_rolling_stats_refined(home_team, match_date, df, ROLLING_WINDOW, location_filter='Home')
    home_team_overall_stats = get_rolling_stats_refined(home_team, match_date, df, ROLLING_WINDOW, location_filter=None)

    away_team_away_stats = get_rolling_stats_refined(away_team, match_date, df, ROLLING_WINDOW, location_filter='Away')
    away_team_overall_stats = get_rolling_stats_refined(away_team, match_date, df, ROLLING_WINDOW, location_filter=None)

    match_stats = {
        f'HomeAvgLast{ROLLING_WINDOW}_GoalsScored_Home': home_team_home_stats.get('GoalsScored', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_GoalsConceded_Home': home_team_home_stats.get('GoalsConceded', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_ShotsOnTarget_Home': home_team_home_stats.get('ShotsOnTarget', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_Corners_Home': home_team_home_stats.get('Corners', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_YellowCards_Home': home_team_home_stats.get('YellowCards', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_Points_Home': home_team_home_stats.get('Points', np.nan),

        f'AwayAvgLast{ROLLING_WINDOW}_GoalsScored_Away': away_team_away_stats.get('GoalsScored', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_GoalsConceded_Away': away_team_away_stats.get('GoalsConceded', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_ShotsOnTarget_Away': away_team_away_stats.get('ShotsOnTarget', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_Corners_Away': away_team_away_stats.get('Corners', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_YellowCards_Away': away_team_away_stats.get('YellowCards', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_Points_Away': away_team_away_stats.get('Points', np.nan),

        f'HomeAvgLast{ROLLING_WINDOW}_GoalsScored_Overall': home_team_overall_stats.get('GoalsScored', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_GoalsConceded_Overall': home_team_overall_stats.get('GoalsConceded', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_ShotsOnTarget_Overall': home_team_overall_stats.get('ShotsOnTarget', np.nan),
        f'HomeAvgLast{ROLLING_WINDOW}_Points_Overall': home_team_overall_stats.get('Points', np.nan),

        f'AwayAvgLast{ROLLING_WINDOW}_GoalsScored_Overall': away_team_overall_stats.get('GoalsScored', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_GoalsConceded_Overall': away_team_overall_stats.get('GoalsConceded', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_ShotsOnTarget_Overall': away_team_overall_stats.get('ShotsOnTarget', np.nan),
        f'AwayAvgLast{ROLLING_WINDOW}_Points_Overall': away_team_overall_stats.get('Points', np.nan),

        f'HomeAttack_vs_AwayDefense_{ROLLING_WINDOW}Avg': home_team_home_stats.get('GoalsScored', np.nan) - away_team_away_stats.get('GoalsConceded', np.nan),
        f'AwayAttack_vs_HomeDefense_{ROLLING_WINDOW}Avg': away_team_away_stats.get('GoalsScored', np.nan) - home_team_home_stats.get('GoalsConceded', np.nan),
    }
    rolling_stats_list.append(match_stats)

rolling_stats_df = pd.DataFrame(rolling_stats_list)
df = pd.merge(df, rolling_stats_df, left_index=True, right_index=True, how='left')

print(f"Rolling average features ({ROLLING_WINDOW} matches) created.")
print("\nDataFrame head with rolling average features:")
rolling_cols_display = [col for col in df.columns if f'AvgLast{ROLLING_WINDOW}' in col][:15]
print(df[['HomeTeam', 'AwayTeam', 'MatchDate'] + rolling_cols_display].head())
# Out:
# Calculating team strength/form features (rolling averages)...
# Calculating 5-Match Rolling Stats:   0%|          | 0/2630 [00:00<?, ?it/s]
# Rolling average features (5 matches) created.
#
# DataFrame head with rolling average features:
#        HomeTeam        AwayTeam  MatchDate  HomeAvgLast5_GoalsScored_Home  \
# 0    Man United       Leicester 2018-08-10                            NaN
# 1   Bournemouth         Cardiff 2018-08-11                            NaN
# 2        Fulham  Crystal Palace 2018-08-11                            NaN
# 3  Huddersfield         Chelsea 2018-08-11                            NaN
# 4     Newcastle       Tottenham 2018-08-11                            NaN
#
#    HomeAvgLast5_GoalsConceded_Home  HomeAvgLast5_ShotsOnTarget_Home  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    HomeAvgLast5_Corners_Home  HomeAvgLast5_YellowCards_Home  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    HomeAvgLast5_Points_Home  AwayAvgLast5_GoalsScored_Away  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#    AwayAvgLast5_GoalsConceded_Away  AwayAvgLast5_ShotsOnTarget_Away  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    AwayAvgLast5_Corners_Away  AwayAvgLast5_YellowCards_Away  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    AwayAvgLast5_Points_Away  HomeAvgLast5_GoalsScored_Overall  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
#
#    HomeAvgLast5_GoalsConceded_Overall  HomeAvgLast5_ShotsOnTarget_Overall
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN

# %%
# Cell 4: Feature Selection and Handling Missing Values (Imputation)

print("Selecting features for PRE-MATCH prediction and handling missing values using Imputation...")

# Define the target variable
TARGET = 'FullTimeResult'
y = df[TARGET].copy() # y is still string labels here

# Define the features to use for PRE-MATCH prediction.
# These are ONLY the rolling average team form features.
rolling_avg_cols = [col for col in df.columns if f'AvgLast{ROLLING_WINDOW}' in col]

if not rolling_avg_cols:
    print("Error: No rolling average columns found. Please check previous cell (Cell 3).")
    raise ValueError("No valid rolling average features found.")

features = rolling_avg_cols
X = df[features].copy()

print("\nSelected Features (VALID FOR PRE-MATCH PREDICTION):")
print(features)
print("\nShape of X (features) BEFORE imputation:", X.shape)
print("Shape of y (target) BEFORE imputation:", y.shape)
print("\nNumber of NaNs per feature column BEFORE imputation:")
print(X.isnull().sum().sort_values(ascending=False).head(10))

# Imputation: Fit on ENTIRE feature set before splitting
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer.fit(X)
X_imputed_array = imputer.transform(X)
X_imputed = pd.DataFrame(X_imputed_array, columns=X.columns, index=X.index)

print(f"\nNumber of rows after imputation: {len(X_imputed)}")
print(f"Number of NaNs per feature column AFTER imputation:")
print(X_imputed.isnull().sum().sum())

X = X_imputed

print("\nFinal shape of features (X):", X.shape)
print("Final shape of target (y):", y.shape)
print("\nFinal Features (X) Head after imputation:")
print(X.head())
print("\nValue counts of target (y) on data used:")
print(y.value_counts())
# Out:
# Selecting features for PRE-MATCH prediction and handling missing values using Imputation...
#
# Selected Features (VALID FOR PRE-MATCH PREDICTION):
# ['HomeAvgLast5_GoalsScored_Home', 'HomeAvgLast5_GoalsConceded_Home', 'HomeAvgLast5_ShotsOnTarget_Home', 'HomeAvgLast5_Corners_Home', 'HomeAvgLast5_YellowCards_Home', 'HomeAvgLast5_Points_Home', 'AwayAvgLast5_GoalsScored_Away', 'AwayAvgLast5_GoalsConceded_Away', 'AwayAvgLast5_ShotsOnTarget_Away', 'AwayAvgLast5_Corners_Away', 'AwayAvgLast5_YellowCards_Away', 'AwayAvgLast5_Points_Away', 'HomeAvgLast5_GoalsScored_Overall', 'HomeAvgLast5_GoalsConceded_Overall', 'HomeAvgLast5_ShotsOnTarget_Overall', 'HomeAvgLast5_Points_Overall', 'AwayAvgLast5_GoalsScored_Overall', 'AwayAvgLast5_GoalsConceded_Overall', 'AwayAvgLast5_ShotsOnTarget_Overall', 'AwayAvgLast5_Points_Overall']
#
# Shape of X (features) BEFORE imputation: (2630, 20)
# Shape of y (target) BEFORE imputation: (2630,)
#
# Number of NaNs per feature column BEFORE imputation:
# HomeAvgLast5_GoalsScored_Home      29
# HomeAvgLast5_GoalsConceded_Home    29
# HomeAvgLast5_ShotsOnTarget_Home    29
# HomeAvgLast5_Corners_Home          29
# HomeAvgLast5_YellowCards_Home      29
# HomeAvgLast5_Points_Home           29
# AwayAvgLast5_GoalsScored_Away      29
# AwayAvgLast5_GoalsConceded_Away    29
# AwayAvgLast5_ShotsOnTarget_Away    29
# AwayAvgLast5_Corners_Away          29
# dtype: int64
#
# Number of rows after imputation: 2630
# Number of NaNs per feature column AFTER imputation:
# 0
#
# Final shape of features (X): (2630, 20)
# Final shape of target (y): (2630,)
#
# Final Features (X) Head after imputation:
#    HomeAvgLast5_GoalsScored_Home  HomeAvgLast5_GoalsConceded_Home  \
# 0                            1.4                              1.2
# 1                            1.4                              1.2
# 2                            1.4                              1.2
# 3                            1.4                              1.2
# 4                            1.4                              1.2
#
#    HomeAvgLast5_ShotsOnTarget_Home  HomeAvgLast5_Corners_Home  \
# 0                              4.6                        5.6
# 1                              4.6                        5.6
# 2                              4.6                        5.6
# 3                              4.6                        5.6
# 4                              4.6                        5.6
#
#    HomeAvgLast5_YellowCards_Home  HomeAvgLast5_Points_Home  \
# 0                            1.6                       1.6
# 1                            1.6                       1.6
# 2                            1.6                       1.6
# 3                            1.6                       1.6
# 4                            1.6                       1.6
#
#    AwayAvgLast5_GoalsScored_Away  AwayAvgLast5_GoalsConceded_Away  \
# 0                            1.2                              1.6
# 1                            1.2                              1.6
# 2                            1.2                              1.6
# 3                            1.2                              1.6
# 4                            1.2                              1.6
#
#    AwayAvgLast5_ShotsOnTarget_Away  AwayAvgLast5_Corners_Away  \
# 0                              4.0                        4.6
# 1                              4.0                        4.6
# 2                              4.0                        4.6
# 3                              4.0                        4.6
# 4                              4.0                        4.6
#
#    AwayAvgLast5_YellowCards_Away  AwayAvgLast5_Points_Away  \
# 0                            1.8                       1.2
# 1                            1.8                       1.2
# 2                            1.8                       1.2
# 3                            1.8                       1.2
# 4                            1.8                       1.2
#
#    HomeAvgLast5_GoalsScored_Overall  HomeAvgLast5_GoalsConceded_Overall  \
# 0                               1.4                                 1.4
# 1                               1.4                                 1.4
# 2                               1.4                                 1.4
# 3                               1.4                                 1.4
# 4                               1.4                                 1.4
#
#    HomeAvgLast5_ShotsOnTarget_Overall  HomeAvgLast5_Points_Overall  \
# 0                                 4.4                          1.4
# 1                                 4.4                          1.4
# 2                                 4.4                          1.4
# 3                                 4.4                          1.4
# 4                                 4.4                          1.4
#
#    AwayAvgLast5_GoalsScored_Overall  AwayAvgLast5_GoalsConceded_Overall  \
# 0                               1.4                                 1.4
# 1                               1.4                                 1.4
# 2                               1.4                                 1.4
# 3                               1.4                                 1.4
# 4                               1.4                                 1.4
#
#    AwayAvgLast5_ShotsOnTarget_Overall  AwayAvgLast5_Points_Overall
# 0                                 4.4                          1.4
# 1                                 4.4                          1.4
# 2                                 4.4                          1.4
# 3                                 4.4                          1.4
# 4                                 4.4                          1.4
#
# Value counts of target (y) on data used:
# FullTimeResult
# H    1163
# A     876
# D     591
# Name: count, dtype: int64

# %%
# Cell 5: Final Data Check Before Modeling

print("Final data check before modeling:")
print("\nFeatures (X) Info:")
X.info()
print("\nTarget (y) Info:")
y.info()
# Out:
# Final data check before modeling:
#
# Features (X) Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   HomeAvgLast5_GoalsScored_Home       2630 non-null   float64
#  1   HomeAvgLast5_GoalsConceded_Home     2630 non-null   float64
#  2   HomeAvgLast5_ShotsOnTarget_Home     2630 non-null   float64
#  3   HomeAvgLast5_Corners_Home           2630 non-null   float64
#  4   HomeAvgLast5_YellowCards_Home       2630 non-null   float64
#  5   HomeAvgLast5_Points_Home            2630 non-null   float64
#  6   AwayAvgLast5_GoalsScored_Away       2630 non-null   float64
#  7   AwayAvgLast5_GoalsConceded_Away     2630 non-null   float64
#  8   AwayAvgLast5_ShotsOnTarget_Away     2630 non-null   float64
#  9   AwayAvgLast5_Corners_Away           2630 non-null   float64
#  10  AwayAvgLast5_YellowCards_Away       2630 non-null   float64
#  11  AwayAvgLast5_Points_Away            2630 non-null   float64
#  12  HomeAvgLast5_GoalsScored_Overall    2630 non-null   float64
#  13  HomeAvgLast5_GoalsConceded_Overall  2630 non-null   float64
#  14  HomeAvgLast5_ShotsOnTarget_Overall  2630 non-null   float64
#  15  HomeAvgLast5_Points_Overall         2630 non-null   float64
#  16  AwayAvgLast5_GoalsScored_Overall    2630 non-null   float64
#  17  AwayAvgLast5_GoalsConceded_Overall  2630 non-null   float64
#  18  AwayAvgLast5_ShotsOnTarget_Overall  2630 non-null   float64
#  19  AwayAvgLast5_Points_Overall         2630 non-null   float64
# dtypes: float64(20)
# memory usage: 411.1 KB
#
# Target (y) Info:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2630 entries, 0 to 2629
# Series name: FullTimeResult
# Non-Null Count  Dtype
# --------------  -----
# 2630 non-null   object
# dtypes: object(1)
# memory usage: 20.7+ KB

# %%
# Cell 6: Data Splitting (Chronological)

print("Splitting data chronologically...")

split_ratio = 0.8
split_index = int(len(X) * split_ratio)

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:] # y_train and y_test are still string labels

print(f"Data split into {split_ratio*100}% train and {(1-split_ratio)*100}% test chronologically.")
print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")

print("\nDate range of Training Set:")
if not X_train.empty:
    print(f"  From: {df.loc[X_train.index[0], 'MatchDate'].date()}")
    print(f"  To:   {df.loc[X_train.index[-1], 'MatchDate'].date()}")
else:
    print("  Training set is empty.")

print("\nDate range of Testing Set:")
if not X_test.empty:
     print(f"  From: {df.loc[X_test.index[0], 'MatchDate'].date()}")
     print(f"  To:   {df.loc[X_test.index[-1], 'MatchDate'].date()}")
else:
    print("  Testing set is empty.")
# Out:
# Splitting data chronologically...
# Data split into 80.0% train and 19.999999999999996% test chronologically.
# Training data shape: (2104, 20)
# Testing data shape: (526, 20)
#
# Date range of Training Set:
#   From: 2018-08-10
#   To:   2024-01-20
#
# Date range of Testing Set:
#   From: 2024-01-20
#   To:   2025-05-05

# %%
# Cell 7: Fit and Save LabelEncoder

print("Fitting LabelEncoder on the full target variable...")

# Fit the encoder on the *entire* target variable (y from before splitting)
label_encoder = LabelEncoder()
label_encoder.fit(df[TARGET]) # Fit on the original y series

print(f"Class mapping: {dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))}")
original_classes_order = label_encoder.classes_ # Store this for evaluation/prediction

print("LabelEncoder fitted.")

# Note: We don't encode y_train or y_test here for fitting the pipeline.
# RandomForestClassifier handles string labels directly.
# Out:
# Fitting LabelEncoder on the full target variable...
# Class mapping: {'A': np.int64(0), 'D': np.int64(1), 'H': np.int64(2)}
# LabelEncoder fitted.

# %%
# Cell 8: Model Pipeline Definition (Scaler + Random Forest with Class Weight Tuning)

print("Defining the model pipeline (StandardScaler + RandomForestClassifier)...")

# Initialize the base model - class_weight will be tuned
rf_model = RandomForestClassifier(random_state=42)

# Create the standard pipeline: Scaling -> Model
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', rf_model)
])

print("Standard Pipeline defined.")

# Define parameter distribution for tuning, including class_weight
param_distributions_rf_tuned = {
    'classifier__n_estimators': randint(100, 800),
    'classifier__max_depth': randint(5, 25),
    'classifier__min_samples_split': randint(2, 20),
    'classifier__min_samples_leaf': randint(1, 15),
    'classifier__max_features': ['sqrt', 'log2', None],
    # Include class_weight options in the tuning
    'classifier__class_weight': [None, 'balanced', 'balanced_subsample']
}

print("\nParameter distributions defined for tuning, including 'class_weight'.")
# Out:
# Defining the model pipeline (StandardScaler + RandomForestClassifier)...
# Standard Pipeline defined.
#
# Parameter distributions defined for tuning, including 'class_weight'.

# %%
# Cell 9: Hyperparameter Tuning (RandomizedSearchCV for Random Forest)

print("Starting Hyperparameter Tuning using RandomizedSearchCV for Random Forest...")

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

random_search_rf = RandomizedSearchCV(
    estimator=pipeline, # Use the standard pipeline
    param_distributions=param_distributions_rf_tuned,
    n_iter=100, # Number of search iterations (adjust as needed)
    scoring='neg_log_loss', # Optimize for Log Loss as requested for probabilities
    cv=cv,
    verbose=2,
    random_state=42,
    n_jobs=-1,
    return_train_score=False
)

# Fit RandomizedSearchCV on the training data (RandomForestClassifier handles string labels)
random_search_rf.fit(X_train, y_train) # Use y_train (string labels) here


print("\nTuned Random Forest Hyperparameter tuning complete.")
print("\nBest parameters found for Random Forest:")
print(random_search_rf.best_params_)
print(f"\nBest cross-validation score (Negative Log Loss): {random_search_rf.best_score_:.4f}")
# Out:
# Starting Hyperparameter Tuning using RandomizedSearchCV for Random Forest...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=9, classifier__n_estimators=120; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=3, classifier__n_estimators=443; total time=   4.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=11, classifier__n_estimators=575; total time=   2.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=19, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=13, classifier__n_estimators=666; total time=   3.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=16, classifier__n_estimators=134; total time=   0.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=16, classifier__n_estimators=134; total time=   0.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=5, classifier__n_estimators=101; total time=   0.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=3, classifier__n_estimators=301; total time=   1.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=3, classifier__n_estimators=301; total time=   1.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=152; total time=   0.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=17, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=16, classifier__n_estimators=164; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=2, classifier__n_estimators=747; total time=   2.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=11, classifier__n_estimators=330; total time=   2.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=11, classifier__n_estimators=330; total time=   2.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=9, classifier__n_estimators=132; total time=   1.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=9, classifier__max_features=None, classifier__min_samples_leaf=12, classifier__min_samples_split=9, classifier__n_estimators=646; total time=   6.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=18, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=306; total time=   3.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=340; total time=   2.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=8, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=3, classifier__n_estimators=781; total time=   3.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=476; total time=   2.3s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=4, classifier__n_estimators=458; total time=   2.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=12, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   3.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=13, classifier__n_estimators=609; total time=   2.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=13, classifier__n_estimators=609; total time=   2.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=6, classifier__n_estimators=724; total time=   6.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=18, classifier__n_estimators=393; total time=   3.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=log2, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=610; total time=   2.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=610; total time=   9.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=19, classifier__n_estimators=250; total time=   1.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=19, classifier__n_estimators=250; total time=   1.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=19, classifier__n_estimators=250; total time=   1.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=19, classifier__n_estimators=250; total time=   1.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=7, classifier__min_samples_split=17, classifier__n_estimators=445; total time=   5.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=403; total time=   2.2s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=10, classifier__n_estimators=332; total time=   1.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=4, classifier__n_estimators=211; total time=   1.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=4, classifier__n_estimators=211; total time=   1.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=437; total time=   1.5s[CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=9, classifier__n_estimators=120; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=3, classifier__n_estimators=443; total time=   4.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=11, classifier__n_estimators=575; total time=   2.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=120; total time=   0.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=120; total time=   0.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=15, classifier__n_estimators=341; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=3, classifier__n_estimators=439; total time=   2.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=5, classifier__n_estimators=101; total time=   0.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=3, classifier__n_estimators=301; total time=   1.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=3, classifier__n_estimators=301; total time=   1.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=152; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=2, classifier__n_estimators=747; total time=   3.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=11, classifier__n_estimators=330; total time=   2.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=11, classifier__n_estimators=330; total time=   2.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=9, classifier__n_estimators=132; total time=   1.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=9, classifier__max_features=None, classifier__min_samples_leaf=12, classifier__min_samples_split=9, classifier__n_estimators=646; total time=   6.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=18, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=306; total time=   3.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=340; total time=   2.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=8, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=3, classifier__n_estimators=781; total time=   3.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=12, classifier__n_estimators=739; total time=   2.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=4, classifier__n_estimators=458; total time=   2.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=791; total time=   8.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=6, classifier__n_estimators=724; total time=   6.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=18, classifier__n_estimators=393; total time=   3.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=log2, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=610; total time=   2.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=610; total time=   9.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=10, classifier__n_estimators=739; total time=  10.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=10, classifier__n_estimators=332; total time=   1.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=10, classifier__n_estimators=332; total time=   1.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=4, classifier__n_estimators=211; total time=   1.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=4, classifier__n_estimators=211; total time=   1.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=437; total time=   1.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=437; total time=   1.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=5, classifier__n_estimators=260; total time=   0.9s
# [CV] END classifier__class_weight=None, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=234; total time=   1.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=234; total time=   1.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=769; total time=   3.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=9, classifier__n_estimators=382; total time=   1.7s[CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=12, classifier__n_estimators=187; total time=   2.2s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=3, classifier__n_estimators=443; total time=   4.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=19, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=13, classifier__n_estimators=666; total time=   3.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=3, classifier__n_estimators=439; total time=   2.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=5, classifier__n_estimators=101; total time=   0.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=5, classifier__n_estimators=576; total time=   2.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=152; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=152; total time=   0.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=17, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=16, classifier__n_estimators=164; total time=   0.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=15, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=9, classifier__n_estimators=774; total time=  13.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=4, classifier__n_estimators=104; total time=   0.3s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=4, classifier__n_estimators=104; total time=   0.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=4, classifier__n_estimators=104; total time=   0.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=4, classifier__n_estimators=104; total time=   0.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=4, classifier__n_estimators=104; total time=   0.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=18, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=306; total time=   3.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=340; total time=   2.2s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=8, classifier__n_estimators=754; total time=   3.2s
# [CV] END classifier__class_weight=None, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=12, classifier__n_estimators=739; total time=   2.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=4, classifier__n_estimators=458; total time=   2.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=12, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   3.9s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=13, classifier__n_estimators=609; total time=   2.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=6, classifier__n_estimators=724; total time=   7.2s
# [CV] END classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=13, classifier__n_estimators=771; total time=   3.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=18, classifier__n_estimators=393; total time=   3.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=448; total time=   6.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=10, classifier__n_estimators=739; total time=  12.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=403; total time=   2.3s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=403; total time=   2.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=10, classifier__n_estimators=332; total time=   1.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=4, classifier__n_estimators=211; total time=   1.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=437; total time=   1.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=437; total time=   1.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=5, classifier__n_estimators=260; total time=   0.9s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=5, classifier__n_estimators=260; total time=   0.9s
# [CV] END classifier__class_weight=None, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=234; total time=   1.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=769; total time=   4.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=2, classifier__n_estimators=383; total time=   1.7s[CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=12, classifier__n_estimators=187; total time=   1.9s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=3, classifier__n_estimators=443; total time=   4.2s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=11, classifier__n_estimators=575; total time=   2.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=120; total time=   0.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=15, classifier__n_estimators=341; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=3, classifier__n_estimators=439; total time=   1.9s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=5, classifier__n_estimators=576; total time=   2.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=15, classifier__n_estimators=351; total time=   1.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=17, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=16, classifier__n_estimators=164; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=2, classifier__n_estimators=747; total time=   2.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=11, classifier__n_estimators=330; total time=   2.9s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=9, classifier__n_estimators=132; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=9, classifier__n_estimators=132; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=9, classifier__n_estimators=132; total time=   1.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=9, classifier__max_features=None, classifier__min_samples_leaf=12, classifier__min_samples_split=9, classifier__n_estimators=646; total time=   7.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=340; total time=   2.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=8, classifier__n_estimators=754; total time=   3.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=12, classifier__n_estimators=739; total time=   3.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=476; total time=   2.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=4, classifier__n_estimators=458; total time=   2.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=791; total time=   9.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   2.0s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   1.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=13, classifier__n_estimators=771; total time=   3.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=log2, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=610; total time=   2.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=448; total time=   6.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=10, classifier__n_estimators=739; total time=  11.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=7, classifier__min_samples_split=17, classifier__n_estimators=445; total time=   5.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=2, classifier__n_estimators=727; total time=  11.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=9, classifier__n_estimators=382; total time=   2.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=2, classifier__n_estimators=383; total time=   1.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=472; total time=   2.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=18, classifier__n_estimators=401; total time=   1.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2, classifier__n_estimators=355; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=19, classifier__max_features=log2, classifier__min_samples_leaf=7, classifier__min_samples_split=3, classifier__n_estimators=738; total time=   3.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=18, classifier__n_estimators=203; total time=   1.0s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=138; total time=   1.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=10, classifier__min_samples_split=4, classifier__n_estimators=507; total time=   5.2s[CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=9, classifier__n_estimators=120; total time=   0.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=12, classifier__n_estimators=187; total time=   2.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=2, classifier__n_estimators=559; total time=   2.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=2, classifier__n_estimators=559; total time=   2.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=19, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=13, classifier__n_estimators=666; total time=   3.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=15, classifier__n_estimators=341; total time=   1.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=16, classifier__n_estimators=134; total time=   0.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=16, classifier__n_estimators=134; total time=   0.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=5, classifier__n_estimators=576; total time=   2.2s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=15, classifier__n_estimators=351; total time=   1.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=17, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=16, classifier__n_estimators=164; total time=   0.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=15, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=9, classifier__n_estimators=774; total time=  12.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=9, classifier__max_features=None, classifier__min_samples_leaf=12, classifier__min_samples_split=9, classifier__n_estimators=646; total time=   6.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=8, classifier__n_estimators=754; total time=   3.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=8, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=3, classifier__n_estimators=781; total time=   3.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=476; total time=   2.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=12, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   3.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=791; total time=   8.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   1.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   1.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=13, classifier__n_estimators=771; total time=   3.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=log2, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=610; total time=   2.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=448; total time=   5.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=610; total time=   9.3s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=19, classifier__n_estimators=250; total time=   1.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=7, classifier__min_samples_split=17, classifier__n_estimators=445; total time=   5.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=10, classifier__n_estimators=332; total time=   1.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=2, classifier__n_estimators=727; total time=  10.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=769; total time=   3.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=17, classifier__n_estimators=758; total time=   3.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=472; total time=   2.2s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=10, classifier__min_samples_split=4, classifier__n_estimators=785; total time=   4.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=19, classifier__max_features=log2, classifier__min_samples_leaf=7, classifier__min_samples_split=3, classifier__n_estimators=738; total time=   3.2s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=14, classifier__n_estimators=119; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=14, classifier__n_estimators=119; total time=   0.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=13, classifier__n_estimators=570; total time=   2.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=13, classifier__n_estimators=570; total time=   2.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=543; total time=   6.1s[CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=9, classifier__n_estimators=120; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=3, classifier__n_estimators=443; total time=   4.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=16, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=11, classifier__n_estimators=575; total time=   2.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=120; total time=   0.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=120; total time=   0.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=15, classifier__n_estimators=341; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=3, classifier__n_estimators=439; total time=   2.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=5, classifier__n_estimators=101; total time=   0.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=3, classifier__n_estimators=301; total time=   1.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=15, classifier__n_estimators=351; total time=   1.3s
# [CV] END classifier__class_weight=None, classifier__max_depth=12, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=19, classifier__n_estimators=152; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=2, classifier__n_estimators=747; total time=   3.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=15, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=9, classifier__n_estimators=774; total time=  14.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=18, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=306; total time=   3.2s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=8, classifier__n_estimators=754; total time=   3.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=8, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=3, classifier__n_estimators=781; total time=   4.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=476; total time=   2.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=12, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   3.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=13, classifier__n_estimators=609; total time=   2.8s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=13, classifier__n_estimators=609; total time=   2.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=6, classifier__n_estimators=724; total time=   7.2s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=18, classifier__n_estimators=393; total time=   3.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=448; total time=   6.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=610; total time=  10.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=7, classifier__min_samples_split=17, classifier__n_estimators=445; total time=   6.0s
# [CV] END classifier__class_weight=None, classifier__max_depth=24, classifier__max_features=sqrt, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=403; total time=   2.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=2, classifier__n_estimators=727; total time=  11.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=9, classifier__n_estimators=382; total time=   2.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=2, classifier__n_estimators=383; total time=   1.7s
# ...
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=4, classifier__min_samples_split=15, classifier__n_estimators=341; total time=   1.4s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=16, classifier__n_estimators=134; total time=   0.6s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=5, classifier__n_estimators=101; total time=   0.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=5, classifier__n_estimators=576; total time=   2.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=15, classifier__n_estimators=351; total time=   1.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=2, classifier__n_estimators=747; total time=   3.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=15, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=9, classifier__n_estimators=774; total time=  14.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=18, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=306; total time=   3.3s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=log2, classifier__min_samples_leaf=5, classifier__min_samples_split=8, classifier__n_estimators=754; total time=   3.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=10, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=12, classifier__n_estimators=739; total time=   3.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=476; total time=   2.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=12, classifier__max_features=None, classifier__min_samples_leaf=9, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   3.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=10, classifier__n_estimators=791; total time=   9.3s
# [CV] END classifier__class_weight=None, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=6, classifier__n_estimators=324; total time=   1.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=13, classifier__n_estimators=771; total time=   3.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=11, classifier__min_samples_split=18, classifier__n_estimators=393; total time=   3.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=448; total time=   6.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=10, classifier__n_estimators=739; total time=  12.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=7, classifier__min_samples_split=17, classifier__n_estimators=445; total time=   5.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=2, classifier__n_estimators=727; total time=  11.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=9, classifier__n_estimators=382; total time=   1.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=2, classifier__n_estimators=383; total time=   1.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=472; total time=   2.3s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=18, classifier__n_estimators=401; total time=   1.5s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=10, classifier__min_samples_split=4, classifier__n_estimators=785; total time=   4.3s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=18, classifier__n_estimators=203; total time=   1.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=17, classifier__n_estimators=138; total time=   1.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=10, classifier__min_samples_split=4, classifier__n_estimators=507; total time=   5.5s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=543; total time=   6.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=13, classifier__min_samples_split=16, classifier__n_estimators=755; total time=   3.3s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=195; total time=   1.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=13, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=195; total time=   1.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=20, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=14, classifier__n_estimators=371; total time=   1.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=20, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=15, classifier__n_estimators=319; total time=   4.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=5, classifier__n_estimators=260; total time=   1.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=9, classifier__min_samples_split=5, classifier__n_estimators=260; total time=   0.9s
# [CV] END classifier__class_weight=None, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=234; total time=   1.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=234; total time=   1.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=15, classifier__n_estimators=769; total time=   3.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=9, classifier__n_estimators=382; total time=   1.7s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=12, classifier__min_samples_split=17, classifier__n_estimators=758; total time=   3.0s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=5, classifier__min_samples_split=18, classifier__n_estimators=401; total time=   1.4s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2, classifier__n_estimators=355; total time=   1.3s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=10, classifier__min_samples_split=4, classifier__n_estimators=785; total time=   4.0s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=14, classifier__max_features=log2, classifier__min_samples_leaf=10, classifier__min_samples_split=18, classifier__n_estimators=203; total time=   1.0s
# [CV] END classifier__class_weight=None, classifier__max_depth=14, classifier__max_features=None, classifier__min_samples_leaf=10, classifier__min_samples_split=4, classifier__n_estimators=507; total time=   5.3s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=6, classifier__max_features=log2, classifier__min_samples_leaf=7, classifier__min_samples_split=18, classifier__n_estimators=791; total time=   3.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=10, classifier__max_features=None, classifier__min_samples_leaf=6, classifier__min_samples_split=12, classifier__n_estimators=543; total time=   6.0s
# [CV] END classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=14, classifier__min_samples_split=18, classifier__n_estimators=219; total time=   0.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=23, classifier__max_features=log2, classifier__min_samples_leaf=7, classifier__min_samples_split=6, classifier__n_estimators=573; total time=   2.9s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=20, classifier__max_features=sqrt, classifier__min_samples_leaf=8, classifier__min_samples_split=14, classifier__n_estimators=371; total time=   1.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=None, classifier__min_samples_leaf=5, classifier__min_samples_split=4, classifier__n_estimators=175; total time=   2.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=19, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=15, classifier__n_estimators=552; total time=   2.1s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=20, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=5, classifier__n_estimators=388; total time=   1.8s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=9, classifier__max_features=None, classifier__min_samples_leaf=10, classifier__min_samples_split=11, classifier__n_estimators=199; total time=   1.9s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=259; total time=   2.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=8, classifier__max_features=None, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=259; total time=   2.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=9, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=267; total time=   3.9s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=15, classifier__max_features=sqrt, classifier__min_samples_leaf=13, classifier__min_samples_split=13, classifier__n_estimators=706; total time=   2.8s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=log2, classifier__min_samples_leaf=8, classifier__min_samples_split=11, classifier__n_estimators=701; total time=   3.9s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=11, classifier__min_samples_split=5, classifier__n_estimators=376; total time=   1.9s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=21, classifier__max_features=None, classifier__min_samples_leaf=4, classifier__min_samples_split=19, classifier__n_estimators=195; total time=   2.7s
# [CV] END classifier__class_weight=None, classifier__max_depth=7, classifier__max_features=sqrt, classifier__min_samples_leaf=14, classifier__min_samples_split=18, classifier__n_estimators=161; total time=   0.6s
# [CV] END classifier__class_weight=None, classifier__max_depth=17, classifier__max_features=None, classifier__min_samples_leaf=3, classifier__min_samples_split=18, classifier__n_estimators=711; total time=   9.7s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=24, classifier__max_features=None, classifier__min_samples_leaf=10, classifier__min_samples_split=16, classifier__n_estimators=243; total time=   2.6s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=20, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=14, classifier__n_estimators=792; total time=   4.1s
# [CV] END classifier__class_weight=balanced_subsample, classifier__max_depth=20, classifier__max_features=sqrt, classifier__min_samples_leaf=7, classifier__min_samples_split=14, classifier__n_estimators=792; total time=   4.1s
# [CV] END classifier__class_weight=None, classifier__max_depth=14, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=18, classifier__n_estimators=352; total time=   1.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=14, classifier__max_features=log2, classifier__min_samples_leaf=12, classifier__min_samples_split=18, classifier__n_estimators=352; total time=   1.4s
# [CV] END classifier__class_weight=balanced, classifier__max_depth=11, classifier__max_features=log2, classifier__min_samples_leaf=13, classifier__min_samples_split=9, classifier__n_estimators=269; total time=   1.0s
# [CV] END classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=None, classifier__min_samples_leaf=10, classifier__min_samples_split=3, classifier__n_estimators=616; total time=   6.5s
# [CV] END classifier__class_weight=None, classifier__max_depth=9, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=9, classifier__n_estimators=595; total time=   2.2s
# Tuned Random Forest Hyperparameter tuning complete.
#
# Best parameters found for Random Forest:
# {'classifier__class_weight': None, 'classifier__max_depth': 7, 'classifier__max_features': 'sqrt', 'classifier__min_samples_leaf': 14, 'classifier__min_samples_split': 18, 'classifier__n_estimators': 161}
#
# Best cross-validation score (Negative Log Loss): -0.9996

# %%
# Cell 10 (Corrected): Final Random Forest Model (Tuned with Class Weight) Training and Evaluation

print("Getting the final tuned Random Forest model pipeline...")

final_rf_pipeline = random_search_rf.best_estimator_

print("Final tuned Random Forest model pipeline ready.")


print("\nEvaluating the FINAL tuned Random Forest model on the test set...")

# Make predictions (string labels: 'A', 'D', 'H' because the pipeline was fitted on strings)
y_pred_final_rf = final_rf_pipeline.predict(X_test) # Variable renamed to avoid confusion with encoded/decoded


# Get predicted probabilities for each class (column order corresponds to pipeline.classes_)
y_pred_proba_final_rf = final_rf_pipeline.predict_proba(X_test)

# --- CORRECTED PART ---
# NO NEED TO DECODE HERE! The predictions from the pipeline are already strings.
# y_pred_final_rf_decoded = label_encoder.inverse_transform(y_pred_final_rf_encoded)
y_pred_final_rf_decoded = y_pred_final_rf # The predictions are already decoded (strings)
# --- END CORRECTED PART ---


# Evaluate Metrics - Use original y_test and the string predictions
accuracy_final_rf = accuracy_score(y_test, y_pred_final_rf_decoded)
conf_matrix_final_rf = confusion_matrix(y_test, y_pred_final_rf_decoded)

# Use original y_test and string predictions for classification report
class_report_final_rf = classification_report(y_test, y_pred_final_rf_decoded, target_names=original_classes_order) # Use original_classes_order


# Calculate Log Loss - use original y_test and probabilities, specifying class order
# The pipeline.classes_ attribute should match original_classes_order
logloss_final_rf = log_loss(y_test, y_pred_proba_final_rf, labels=original_classes_order) # labels= ensures columns map correctly


print(f"\nFinal Tuned Random Forest Accuracy: {accuracy_final_rf:.4f}")
print("\nFinal Tuned Random Forest Confusion Matrix:")
sns.heatmap(conf_matrix_final_rf, annot=True, fmt='d', cmap='Blues', xticklabels=original_classes_order, yticklabels=original_classes_order)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Final Tuned Random Forest Confusion Matrix (Test Set)")
plt.show()

print("\nFinal Tuned Random Forest Classification Report:")
print(class_report_final_rf)

print(f"\nFinal Tuned Random Forest Log Loss: {logloss_final_rf:.4f}")

print("\nKey check: Look at the 'D' row in the Classification Report.")
print("  - Is the 'support' value correct (should match the number of draws in your test set)?")
print("  - Are the 'precision' and 'recall' values for 'D' non-zero?")
# Out:
# Getting the final tuned Random Forest model pipeline...
# Final tuned Random Forest model pipeline ready.
#
# Evaluating the FINAL tuned Random Forest model on the test set...
#
# Final Tuned Random Forest Accuracy: 0.5133
#
# Final Tuned Random Forest Confusion Matrix:
# Final Tuned Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.50      0.52      0.51       174
#            D       0.00      0.00      0.00       130
#            H       0.52      0.81      0.63       222
#
#     accuracy                           0.51       526
#    macro avg       0.34      0.44      0.38       526
# weighted avg       0.38      0.51      0.44       526
#
#
# Final Tuned Random Forest Log Loss: 1.0101
#
# Key check: Look at the 'D' row in the Classification Report.
#   - Is the 'support' value correct (should match the number of draws in your test set)?
#   - Are the 'precision' and 'recall' values for 'D' non-zero?

# %%
# Cell 11: Save Model and Preprocessors

print("Saving the final model pipeline, imputer, and label encoder...")

save_dir_final_rf_weighted = 'model_assets_rf_weighted' # Use a specific directory name
os.makedirs(save_dir_final_rf_weighted, exist_ok=True)

model_pipeline_path_final_rf_weighted = os.path.join(save_dir_final_rf_weighted, 'full_prediction_pipeline_rf_weighted.joblib')
joblib.dump(final_rf_pipeline, model_pipeline_path_final_rf_weighted)

imputer_path_final_rf_weighted = os.path.join(save_dir_final_rf_weighted, 'imputer.joblib')
joblib.dump(imputer, imputer_path_final_rf_weighted) # Save the imputer fitted in Cell 4

label_encoder_path_final_rf_weighted = os.path.join(save_dir_final_rf_weighted, 'label_encoder.joblib')
joblib.dump(label_encoder, label_encoder_path_final_rf_weighted) # Save the encoder fitted in Cell 7


print(f"Final model pipeline saved to: {model_pipeline_path_final_rf_weighted}")
print(f"Fitted Imputer saved to: {imputer_path_final_rf_weighted}")
print(f"Fitted LabelEncoder saved to: {label_encoder_path_final_rf_weighted}")
print("\nSaved assets can be loaded for prediction.")
# Out:
# Saving the final model pipeline, imputer, and label encoder...
# Final model pipeline saved to: model_assets_rf_weighted/full_prediction_pipeline_rf_weighted.joblib
# Fitted Imputer saved to: model_assets_rf_weighted/imputer.joblib
# Fitted LabelEncoder saved to: model_assets_rf_weighted/label_encoder.joblib
#
# Saved assets can be loaded for prediction.

# %%
# Cell 12: Design the Prediction Pipeline Function

print("Designing the prediction pipeline function...")

# Copy get_rolling_stats_refined function here for self-containment
def get_rolling_stats_refined(team, match_date, df_sorted, window_size, location_filter=None):
    required_cols = ['MatchDate', 'HomeTeam', 'AwayTeam', 'FullTimeResult',
                     'FullTimeHomeGoals', 'FullTimeAwayGoals',
                     'HomeShots', 'AwayShots', 'HomeShotsOnTarget', 'AwayShotsOnTarget',
                     'HomeCorners', 'AwayCorners', 'HomeFouls', 'AwayFouls',
                     'HomeYellowCards', 'AwayYellowCards', 'HomeRedCards', 'AwayRedCards']

    team_matches = df_sorted[df_sorted['MatchDate'] < match_date].copy()
    team_matches_filtered = team_matches[(team_matches['HomeTeam'] == team) | (team_matches['AwayTeam'] == team)]

    if location_filter == 'Home':
        team_matches_filtered = team_matches_filtered[team_matches_filtered['HomeTeam'] == team]
    elif location_filter == 'Away':
        team_matches_filtered = team_matches_filtered[team_matches_filtered['AwayTeam'] == team]

    recent_matches = team_matches_filtered.sort_values(by='MatchDate').tail(window_size)

    if recent_matches.empty:
        return {}

    stats = {}
    valid_matches_results = recent_matches.dropna(subset=['FullTimeResult', 'HomeTeam', 'AwayTeam'])

    if not valid_matches_results.empty:
         points = valid_matches_results.apply(lambda row:
             3 if (row['HomeTeam'] == team and row['FullTimeResult'] == 'H') or \
                  (row['AwayTeam'] == team and row['FullTimeResult'] == 'A') else \
             1 if row['FullTimeResult'] == 'D' else \
             0, axis=1)
         stats['Points'] = points.mean()
    else:
         stats['Points'] = np.nan


    valid_matches_goals = recent_matches.dropna(subset=['FullTimeHomeGoals', 'FullTimeAwayGoals'])
    if not valid_matches_goals.empty:
        stats['GoalsScored'] = valid_matches_goals.apply(lambda row: row['FullTimeHomeGoals'] if row['HomeTeam'] == team else row['FullTimeAwayGoals'], axis=1).mean()
        stats['GoalsConceded'] = valid_matches_goals.apply(lambda row: row['FullTimeAwayGoals'] if row['HomeTeam'] == team else row['FullTimeHomeGoals'], axis=1).mean()
    else:
        stats['GoalsScored'] = np.nan
        stats['GoalsConceded'] = np.nan


    for col in ['Shots', 'ShotsOnTarget', 'Corners', 'Fouls', 'YellowCards', 'RedCards']:
        home_col = f'Home{col}'
        away_col = f'Away{col}'
        if home_col in recent_matches.columns and away_col in recent_matches.columns:
             valid_matches_stat = recent_matches.dropna(subset=[home_col, away_col])
             if not valid_matches_stat.empty:
                stats[col] = valid_matches_stat.apply(lambda row: row[home_col] if row['HomeTeam'] == team else row[away_col], axis=1).mean()
             else:
                stats[col] = np.nan
        else:
             stats[col] = np.nan

    return stats

# Ensure ROLLING_WINDOW is defined
ROLLING_WINDOW = 5

# Define the path where assets were saved in Cell 11
save_dir_final_rf_weighted = 'model_assets_rf_weighted'
model_pipeline_path_final_rf_weighted = os.path.join(save_dir_final_rf_weighted, 'full_prediction_pipeline_rf_weighted.joblib')
imputer_path_final_rf_weighted = os.path.join(save_dir_final_rf_weighted, 'imputer.joblib')
label_encoder_path_final_rf_weighted = os.path.join(save_dir_final_rf_weighted, 'label_encoder.joblib')

# Load the saved model and preprocessors
try:
    loaded_pipeline_final_rf_weighted = joblib.load(model_pipeline_path_final_rf_weighted)
    loaded_imputer_final_rf_weighted = joblib.load(imputer_path_final_rf_weighted)
    loaded_label_encoder_final_rf_weighted = joblib.load(label_encoder_path_final_rf_weighted)

    # Get the list of expected features from the trained pipeline's scaler step
    expected_features_final_rf_weighted = list(loaded_pipeline_final_rf_weighted.named_steps['scaler'].feature_names_in_)

    print("Model and preprocessors loaded successfully for prediction function.")
    print(f"Prediction function expects {len(expected_features_final_rf_weighted)} features.")
    # Print the order of classes the model expects probabilities for (from the encoder)
    print(f"Model probability output order corresponds to classes: {loaded_label_encoder_final_rf_weighted.classes_}")


except (FileNotFoundError, AttributeError) as e:
    print(f"Error loading model assets: {e}. Please ensure Cell 11 was run successfully.")
    loaded_pipeline_final_rf_weighted = None
    loaded_imputer_final_rf_weighted = None
    loaded_label_encoder_final_rf_weighted = None
    expected_features_final_rf_weighted = []


# --- The Prediction Function ---
def predict_epl_outcome(home_team, away_team, match_date_str, historical_df, model_pipeline, imputer, label_encoder, expected_features, window_size=5):
    """
    Predicts the outcome probabilities for a given EPL match using loaded assets.
    """
    if model_pipeline is None or imputer is None or label_encoder is None or not expected_features:
        print("Prediction failed: Model or preprocessors not loaded correctly.")
        return None

    try:
        match_date = pd.to_datetime(match_date_str)
    except ValueError:
        print(f"Error: Invalid match_date_str format: {match_date_str}. Use YYYY-MM-DD.")
        return None

    all_teams = pd.concat([historical_df['HomeTeam'], historical_df['AwayTeam']]).unique()
    if home_team not in all_teams or away_team not in all_teams:
        print(f"Error: One or both teams ('{home_team}', '{away_team}') not found in historical data.")
        return None

    # 1. Calculate rolling averages
    historical_df_sorted = historical_df.sort_values(by='MatchDate').reset_index(drop=True)
    home_stats = get_rolling_stats_refined(home_team, match_date, historical_df_sorted, window_size, location_filter='Home')
    home_stats_overall = get_rolling_stats_refined(home_team, match_date, historical_df_sorted, window_size, location_filter=None)
    away_stats = get_rolling_stats_refined(away_team, match_date, historical_df_sorted, window_size, location_filter='Away')
    away_stats_overall = get_rolling_stats_refined(away_team, match_date, historical_df_sorted, window_size, location_filter=None)

    home_attack_away_defense = home_stats.get('GoalsScored', np.nan) - away_stats.get('GoalsConceded', np.nan)
    away_attack_home_defense = away_stats.get('GoalsScored', np.nan) - home_stats.get('GoalsConceded', np.nan)

    # 2. Create feature DataFrame
    match_features_dict = {
        f'HomeAvgLast{window_size}_GoalsScored_Home': home_stats.get('GoalsScored', np.nan),
        f'HomeAvgLast{window_size}_GoalsConceded_Home': home_stats.get('GoalsConceded', np.nan),
        f'HomeAvgLast{window_size}_ShotsOnTarget_Home': home_stats.get('ShotsOnTarget', np.nan),
        f'HomeAvgLast{window_size}_Corners_Home': home_stats.get('Corners', np.nan),
        f'HomeAvgLast{window_size}_YellowCards_Home': home_stats.get('YellowCards', np.nan),
        f'HomeAvgLast{window_size}_Points_Home': home_stats.get('Points', np.nan),

        f'AwayAvgLast{window_size}_GoalsScored_Away': away_stats.get('GoalsScored', np.nan),
        f'AwayAvgLast{window_size}_GoalsConceded_Away': away_stats.get('GoalsConceded', np.nan),
        f'AwayAvgLast{window_size}_ShotsOnTarget_Away': away_stats.get('ShotsOnTarget', np.nan),
        f'AwayAvgLast{window_size}_Corners_Away': away_stats.get('Corners', np.nan),
        f'AwayAvgLast{window_size}_YellowCards_Away': away_stats.get('YellowCards', np.nan),
        f'AwayAvgLast{window_size}_Points_Away': away_stats.get('Points', np.nan),

        f'HomeAvgLast{window_size}_GoalsScored_Overall': home_stats_overall.get('GoalsScored', np.nan),
        f'HomeAvgLast{window_size}_GoalsConceded_Overall': home_stats_overall.get('GoalsConceded', np.nan),
        f'HomeAvgLast{window_size}_ShotsOnTarget_Overall': home_stats_overall.get('ShotsOnTarget', np.nan),
        f'HomeAvgLast{window_size}_Points_Overall': home_stats_overall.get('Points', np.nan),

        f'AwayAvgLast{window_size}_GoalsScored_Overall': away_stats_overall.get('GoalsScored', np.nan),
        f'AwayAvgLast{window_size}_GoalsConceded_Overall': away_stats_overall.get('GoalsConceded', np.nan),
        f'AwayAvgLast{window_size}_ShotsOnTarget_Overall': away_stats_overall.get('ShotsOnTarget', np.nan),
        f'AwayAvgLast{window_size}_Points_Overall': away_stats_overall.get('Points', np.nan),

        f'HomeAttack_vs_AwayDefense_{window_size}Avg': home_attack_away_defense,
        f'AwayAttack_vs_HomeDefense_{window_size}Avg': away_attack_home_defense,
    }

    X_new = pd.DataFrame([match_features_dict])
    X_new = X_new.reindex(columns=expected_features)

    # 3. Impute missing values
    X_new_imputed_array = imputer.transform(X_new)
    X_new_imputed = pd.DataFrame(X_new_imputed_array, columns=X_new.columns, index=X_new.index)

    # 4. Make the probability prediction
    prediction_proba_array = model_pipeline.predict_proba(X_new_imputed)

    # 5. Format the output
    # Use the loaded label_encoder to get original string labels in the correct order
    class_labels_order = label_encoder.classes_ # ['A', 'D', 'H']

    prediction_proba_dict = dict(zip(class_labels_order, prediction_proba_array[0]))

    return prediction_proba_dict

# --- Example Usage ---
if loaded_pipeline_final_rf_weighted is not None and loaded_imputer_final_rf_weighted is not None and loaded_label_encoder_final_rf_weighted is not None and len(expected_features_final_rf_weighted) > 0:

    print("\n--- Example Prediction ---")
    try:
        # Example from the test set
        # Ensure X_test is available from Cell 6
        first_test_match_index = X_test.index[0]
        first_test_match = df.loc[first_test_match_index]

        example_home_team = first_test_match['HomeTeam']
        example_away_team = first_test_match['AwayTeam']
        example_match_date_dt = pd.to_datetime(first_test_match['MatchDate']) # Ensure datetime
        example_match_date_str = example_match_date_dt.strftime('%Y-%m-%d')
        actual_result = first_test_match['FullTimeResult']

        print(f"Predicting match from test set: {example_home_team} vs {example_away_team} on {example_match_date_str}")

        predicted_probabilities = predict_epl_outcome(
            home_team=example_home_team,
            away_team=example_away_team,
            match_date_str=example_match_date_str,
            historical_df=df,
            model_pipeline=loaded_pipeline_final_rf_weighted,
            imputer=loaded_imputer_final_rf_weighted,
            label_encoder=loaded_label_encoder_final_rf_weighted,
            expected_features=expected_features_final_rf_weighted,
            window_size=ROLLING_WINDOW
        )

        if predicted_probabilities:
            print("\nPredicted Probabilities:")
            print(predicted_probabilities)
            predicted_outcome = max(predicted_probabilities, key=predicted_probabilities.get)
            print(f"Most likely outcome: {predicted_outcome}")
            print(f"Actual outcome: {actual_result}")
        else:
            print("Example prediction failed.")

        # Hypothetical future match
        latest_date_in_df = df['MatchDate'].max()
        future_date_dt = latest_date_in_df + pd.Timedelta(days=30)
        example_home_team_future = 'Man City'
        example_away_team_future = 'Arsenal'

        all_teams_in_df = pd.concat([df['HomeTeam'], df['AwayTeam']]).unique()
        if example_home_team_future in all_teams_in_df and example_away_team_future in all_teams_in_df:
            print(f"\nPredicting a hypothetical future match: {example_home_team_future} vs {example_away_team_future} on {future_date_dt.date()}")
            predicted_probabilities_future = predict_epl_outcome(
                home_team=example_home_team_future,
                away_team=example_away_team_future,
                match_date_str=future_date_dt.strftime('%Y-%m-%d'),
                historical_df=df,
                model_pipeline=loaded_pipeline_final_rf_weighted,
                imputer=loaded_imputer_final_rf_weighted,
                label_encoder=loaded_label_encoder_final_rf_weighted,
                expected_features=expected_features_final_rf_weighted,
                window_size=ROLLING_WINDOW
            )
            if predicted_probabilities_future:
                 print("\nHypothetical Predicted Probabilities:")
                 print(predicted_probabilities_future)
                 predicted_outcome_future = max(predicted_probabilities_future, key=predicted_probabilities_future.get)
                 print(f"Most likely hypothetical outcome: {predicted_outcome_future}")
        else:
             print(f"\nSkipping hypothetical future prediction: One or both teams ('{example_home_team_future}', '{example_away_team_future}') not found in historical data.")


    except NameError:
        print("\nError: X_test not found. Run Cell 6 to define X_test.")
        print("Cannot run example prediction.")


else:
    print("\nCannot run example prediction: Model, preprocessors, or feature list not loaded correctly.")
# Out:
# Designing the prediction pipeline function...
# Model and preprocessors loaded successfully for prediction function.
# Prediction function expects 20 features.
# Model probability output order corresponds to classes: ['A' 'D' 'H']
#
# --- Example Prediction ---
# Predicting match from test set: Brentford vs Nott'm Forest on 2024-01-20
#
# Predicted Probabilities:
# {'A': np.float64(0.30427870028085025), 'D': np.float64(0.2708458380734821), 'H': np.float64(0.42487546164566775)}
# Most likely outcome: H
# Actual outcome: H
#
# Predicting a hypothetical future match: Man City vs Arsenal on 2025-06-04
#
# Hypothetical Predicted Probabilities:
# {'A': np.float64(0.2823045553603368), 'D': np.float64(0.22744780494909728), 'H': np.float64(0.4902476396905661)}
# Most likely hypothetical outcome: H
